# %% [markdown]
# <a href="https://colab.research.google.com/github/rahuls569/EVA8/blob/main/Assignment_7/Assignment7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision
from __future__ import print_function

# Load modules/models from EVA course

# !git clone https://github.com/rahuls569/Main_Repo -q --quiet
# !mv Main_Repo/* .
# !rm -rf Main_Repo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# mv: cannot move 'Main_Repo/models' to './models': Directory not empty

# %%
# !pip install -U git+https://github.com/albu/albumentations -q --quiet
# Out:
#   Preparing metadata (setup.py) ... done

# %% [markdown]
# # Loading train and test data with transforms and loader functions

# %%
from main import *

# %%
Batch =128
SEED=1
root= './data'
trainset, testset, classes = load_cifar10(root, augmentations=augmentations)
train_loader, test_loader= setup_dataloaders(trainset, testset, SEED, Batch)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # Images from Train Loader

# %%
from utils import *
import torch
channel_means = (0.5, 0.5, 0.5)
channel_stdevs = (0.5, 0.5, 0.5)

your_class_obj = YourClass(train_loader, classes, channel_means, channel_stdevs)
your_class_obj.display_images()
# Out:
# Image 0: ship
# Image 1: bird
# Image 2: cat
# Image 3: dog
# Image 4: bird
# Image 5: truck
# Image 6: truck
# Image 7: plane
# Image 8: plane
# Image 9: ship
# Image 10: truck
# Image 11: frog
# Image 12: bird
# Image 13: bird
# Image 14: dog
# Image 15: frog
# Image 16: ship
# Image 17: deer
# Image 18: horse
# Image 19: truck
# Image 20: horse
# Image 21: horse
# Image 22: dog
# Image 23: cat
# Image 24: cat
# Image 25: truck
# Image 26: ship
# Image 27: plane
# Image 28: car
# Image 29: truck
# Image 30: frog
# Image 31: frog

# %%
from models.resnet import *
import torch

# %% [markdown]
# # Load ResNet18 Model

# %%
# Loading ResNet18 Model
net = ResNet18()
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print(device)

# Sending network to device
net = net.to(device)
# Out:
# cuda

# %% [markdown]
# # Torch Summary

# %%
# !pip install torchsummary
from torchsummary import summary

# Model Summary
summary(net, input_size=(3, 32, 32))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
# ...

# %% [markdown]
# # EPOCHS

# %%
EPOCHS=25
Trainer1, tester=trainNetwork(net, device, train_loader, test_loader, EPOCHS, lr=0.2)
# Out:
# EPOCH: 0
# Loss=1.720841646194458 Batch_id=390 Accuracy=21.55: 100%|██████████| 391/391 [00:47<00:00,  8.17it/s]
# Test set: Average loss: 0.0145, Accuracy: 2978/10000 (29.78%)
#
# EPOCH: 1
# Loss=1.506486177444458 Batch_id=390 Accuracy=36.28: 100%|██████████| 391/391 [00:46<00:00,  8.44it/s]
# Test set: Average loss: 0.0124, Accuracy: 4149/10000 (41.49%)
#
# EPOCH: 2
# Loss=1.5015265941619873 Batch_id=390 Accuracy=45.34: 100%|██████████| 391/391 [00:47<00:00,  8.23it/s]
# Test set: Average loss: 0.0113, Accuracy: 4713/10000 (47.13%)
#
# EPOCH: 3
# Loss=1.3899298906326294 Batch_id=390 Accuracy=51.18: 100%|██████████| 391/391 [00:46<00:00,  8.32it/s]
# Test set: Average loss: 0.0102, Accuracy: 5325/10000 (53.25%)
#
# EPOCH: 4
# Loss=1.1168392896652222 Batch_id=390 Accuracy=57.16: 100%|██████████| 391/391 [00:46<00:00,  8.35it/s]
# Test set: Average loss: 0.0094, Accuracy: 5760/10000 (57.60%)
#
# EPOCH: 5
# ...

# %% [markdown]
# # GRAPH Loss and Accuracy

# %%
Graph_loss_accuracy(Trainer1, tester, EPOCHS)

# %% [markdown]
# # Misclassified_images

# %%
plot_misclassified_images(tester.misclassified_images, classes)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %% [markdown]
# # Accuracy

# %%
Class_Accuracy(net, test_loader, classes, device)
# Out:
# Accuracy of plane : 93 %
# Accuracy of   car : 93 %
# Accuracy of  bird : 57 %
# Accuracy of   cat : 61 %
# Accuracy of  deer : 56 %
# Accuracy of   dog : 61 %
# Accuracy of  frog : 80 %
# Accuracy of horse : 71 %
# Accuracy of  ship : 75 %
# Accuracy of truck : 87 %

# %% [markdown]
# # Classified Images

# %%
import matplotlib.pyplot as plt
plot_classified_images(tester.classified_images, classes)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %% [markdown]
# # Grad CAM Images

# %%
import torch.nn.functional as F

Grad_CAM(net, test_loader, classes, device)
